# %% [markdown]
# ## Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pathlib

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Get dataset

# %%
data_dir = pathlib.Path("./LaptopVsPc/training")
test_dir = pathlib.Path("./LaptopVsPc/test")

# %% [markdown]
# ## Analyse data

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 270

# %%
laptops = list(data_dir.glob('laptop/*'))
PIL.Image.open(str(laptops[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=159x159 at 0x7FCCBB672B20>

# %%
pc = list(data_dir.glob('pc/*'))
PIL.Image.open(str(pc[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=266x189 at 0x7FCCBB68EE80>

# %% [markdown]
# ## Create dataset

# %%
train_image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=(0.9, 1.1),
    horizontal_flip=True,
    vertical_flip=False
)

IMG_HEIGHT, IMG_WIDTH = 180, 180
batch_size = 32

train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=data_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH))

test_data_gen = train_image_generator.flow_from_directory(directory=test_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH))

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=batch_size)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_dir,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=batch_size)

print(train_data_gen.class_indices)
# Out:
# Found 270 images belonging to 2 classes.
# Found 110 images belonging to 2 classes.
# Found 270 files belonging to 2 classes.
# Using 216 files for training.
# Found 270 files belonging to 2 classes.
# Using 54 files for validation.
# Found 110 files belonging to 2 classes.
# {'laptop': 0, 'pc': 1}

# %% [markdown]
# ## Look at generated samples

# %%
sample_training_images, labels = next(train_data_gen)
class_label = {v:k for k,v in train_data_gen.class_indices.items()}
fig, axes = plt.subplots(4, 4, figsize=(20,10))
axes = axes.flatten()
for img, label, ax in zip(sample_training_images, labels, axes):
    ax.set_title(class_label[np.argmax(label)])
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()

# %% [markdown]
# ## Create model

# %% [markdown]
# ### Model with 10 layers

# %%
num_classes = 2

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Model with 8 layers

# %%
model2 = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Model with 6 layers

# %%
model3 = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile models

# %%
model.compile(optimizer='adam',
          loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=['accuracy'])

model2.compile(optimizer='adam',
          loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=['accuracy'])

model3.compile(optimizer='adam',
          loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=['accuracy'])

# %%
print('\nModel with 10 Layers:\n')
model.summary()
print('\nModel with 8 Layers:\n')
model2.summary()
print('\nModel with 6 Layers:\n')
model3.summary()
# Out:
# Model with 10 Layers:
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 3,988,898
# Trainable params: 3,988,898
# Non-trainable params: 0
# _________________________________________________________________
#
# Model with 8 Layers:
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 90, 90, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 129600)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16588928
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 16,608,578
# Trainable params: 16,608,578
# Non-trainable params: 0
# _________________________________________________________________
#
# Model with 6 Layers:
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 180, 180, 64)      1792
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 90, 90, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 518400)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               66355328
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 66,357,378
# Trainable params: 66,357,378
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training models

# %%
epochs = 5

history = model.fit(
  train_ds,
  validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/5
# 7/7 [==============================] - 3s 414ms/step - loss: 0.7965 - accuracy: 0.5602 - val_loss: 0.6780 - val_accuracy: 0.4259
# Epoch 2/5
# 7/7 [==============================] - 3s 391ms/step - loss: 0.5613 - accuracy: 0.8148 - val_loss: 0.4615 - val_accuracy: 0.8333
# Epoch 3/5
# 7/7 [==============================] - 3s 386ms/step - loss: 0.3620 - accuracy: 0.8657 - val_loss: 0.2370 - val_accuracy: 0.9444
# Epoch 4/5
# 7/7 [==============================] - 3s 394ms/step - loss: 0.1975 - accuracy: 0.9306 - val_loss: 0.1534 - val_accuracy: 0.9630
# Epoch 5/5
# 7/7 [==============================] - 3s 469ms/step - loss: 0.1488 - accuracy: 0.9444 - val_loss: 0.3425 - val_accuracy: 0.8519

# %%
def plot_train_val_loss_and_acc(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
plot_train_val_loss_and_acc(history)

# %%
history2 = model2.fit(
  train_ds,
  validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/5
# 7/7 [==============================] - 6s 831ms/step - loss: 2.0187 - accuracy: 0.5880 - val_loss: 0.6857 - val_accuracy: 0.5000
# Epoch 2/5
# 7/7 [==============================] - 6s 801ms/step - loss: 0.5101 - accuracy: 0.7639 - val_loss: 0.4224 - val_accuracy: 0.7778
# Epoch 3/5
# 7/7 [==============================] - 5s 706ms/step - loss: 0.3226 - accuracy: 0.8657 - val_loss: 0.2501 - val_accuracy: 0.9074
# Epoch 4/5
# 7/7 [==============================] - 5s 705ms/step - loss: 0.1756 - accuracy: 0.9537 - val_loss: 0.1737 - val_accuracy: 0.9444
# Epoch 5/5
# 7/7 [==============================] - 5s 697ms/step - loss: 0.1107 - accuracy: 0.9676 - val_loss: 0.1884 - val_accuracy: 0.9444

# %%
plot_train_val_loss_and_acc(history2)

# %%
history3 = model3.fit(
  train_ds,
  validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/5
# 7/7 [==============================] - 7s 1s/step - loss: 26.0342 - accuracy: 0.5370 - val_loss: 11.5661 - val_accuracy: 0.4074
# Epoch 2/5
# 7/7 [==============================] - 7s 941ms/step - loss: 4.0282 - accuracy: 0.6944 - val_loss: 0.6016 - val_accuracy: 0.8704
# Epoch 3/5
# 7/7 [==============================] - 7s 958ms/step - loss: 0.4744 - accuracy: 0.9074 - val_loss: 0.3816 - val_accuracy: 0.9259
# Epoch 4/5
# 7/7 [==============================] - 7s 951ms/step - loss: 0.1966 - accuracy: 0.9306 - val_loss: 0.1369 - val_accuracy: 0.9630
# Epoch 5/5
# 7/7 [==============================] - 7s 990ms/step - loss: 0.0356 - accuracy: 0.9815 - val_loss: 0.1593 - val_accuracy: 0.9259

# %%
plot_train_val_loss_and_acc(history3)

# %% [markdown]
# ## Metrics

# %%
def print_metrics(test_ds, model):
    score = model.evaluate(test_ds)
    evaluate_metrics = dict(zip(model.metrics_names, score))
    print('\n', evaluate_metrics)
    
    predictions = model.predict(test_ds, verbose=0)
    labels = np.array([x[1].numpy() for x in list(test_ds)])

    def take_label(x):
        if x[0] > x[1]:
            return 0
        else:
            return 1

    predictions = np.array([take_label(xi) for xi in predictions])
    labels = np.concatenate(labels).ravel()

    tn = tf.keras.metrics.TrueNegatives()
    tn.update_state(predictions, labels)
    print("True Negatives: ", tn.result().numpy())
    tp = tf.keras.metrics.TruePositives()
    tp.update_state(predictions, labels)
    print("True Positives: ", tp.result().numpy())
    fn = tf.keras.metrics.FalseNegatives()
    fn.update_state(predictions, labels)
    print("False Negatives: ", fn.result().numpy())
    fp = tf.keras.metrics.FalsePositives()
    fp.update_state(predictions, labels)
    print("False Positives: ", fp.result().numpy())
    auc = tf.keras.metrics.AUC()
    auc.update_state(predictions, labels)
    print("AUC: ", auc.result().numpy())

# %%
print_metrics(test_ds, model)
# Out:
# 4/4 [==============================] - 0s 106ms/step - loss: 0.5421 - accuracy: 0.8455
#
#  {'loss': 0.5420519113540649, 'accuracy': 0.8454545736312866}
# True Negatives:  25.0
# True Positives:  30.0
# False Negatives:  35.0
# False Positives:  20.0
# AUC:  0.508547

# %%
print_metrics(test_ds, model2)
# Out:
# 4/4 [==============================] - 1s 152ms/step - loss: 0.3764 - accuracy: 0.8727
#
#  {'loss': 0.37642988562583923, 'accuracy': 0.8727272748947144}
# True Negatives:  41.0
# True Positives:  25.0
# False Negatives:  19.0
# False Positives:  25.0
# AUC:  0.59469694

# %%
print_metrics(test_ds, model3)
# Out:
# 4/4 [==============================] - 1s 164ms/step - loss: 0.7372 - accuracy: 0.8909
#
#  {'loss': 0.7372050285339355, 'accuracy': 0.8909090757369995}
# True Negatives:  37.0
# True Positives:  19.0
# False Negatives:  23.0
# False Positives:  31.0
# AUC:  0.49824932

# %% [markdown]
# ## Model with generated images

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              # metrics cannot calculate roc curve "metrics=[tf.keras.metrics.AUC()]", 
              # since the model would then get an InvalidArgument error
              metrics=['accuracy'])
               
history4 = model.fit(train_data_gen,
          steps_per_epoch=image_count / batch_size, epochs=epochs)
# Out:
# Epoch 1/5
# 9/8 [================================] - 5s 521ms/step - loss: 7.2830 - accuracy: 0.4519
# Epoch 2/5
# 9/8 [================================] - 5s 522ms/step - loss: 7.2830 - accuracy: 0.4519
# Epoch 3/5
# 9/8 [================================] - 4s 489ms/step - loss: 7.2830 - accuracy: 0.4519
# Epoch 4/5
# 9/8 [================================] - 5s 519ms/step - loss: 7.2830 - accuracy: 0.4519
# Epoch 5/5
# 9/8 [================================] - 4s 483ms/step - loss: 7.2830 - accuracy: 0.4519

# %%
acc = history.history['accuracy']

loss = history.history['loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()

# %%
print_metrics(test_data_gen, model)
# Out:
# 4/4 [==============================] - 1s 197ms/step - loss: 7.3264 - accuracy: 0.4545
#
#  {'loss': 7.326406955718994, 'accuracy': 0.4545454680919647}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-359bc2dd1067> in <module>
# ----> 1 print_metrics(test_data_gen, model)
#
# <ipython-input-20-2eeed97a3112> in print_metrics(test_ds, model)
#       5
#       6     predictions = model.predict(test_ds, verbose=0)
# ----> 7     labels = np.array([x[1].numpy() for x in list(test_ds)])
#       8
#       9     def take_label(x):
#
# /opt/conda/lib/python3.8/site-packages/keras_preprocessing/image/iterator.py in __next__(self, *args, **kwargs)
#     102
#     103     def __next__(self, *args, **kwargs):
# --> 104         return self.next(*args, **kwargs)
#     105
#     106     def next(self):
#
# /opt/conda/lib/python3.8/site-packages/keras_preprocessing/image/iterator.py in next(self)
#     114         # The transformation of images is not under thread lock
#     115         # so it can be done in parallel
# --> 116         return self._get_batches_of_transformed_samples(index_array)
#     117
#     118     def _get_batches_of_transformed_samples(self, index_array):
#
# /opt/conda/lib/python3.8/site-packages/keras_preprocessing/image/iterator.py in _get_batches_of_transformed_samples(self, index_array)
#     236             if self.image_data_generator:
#     237                 params = self.image_data_generator.get_random_transform(x.shape)
# --> 238                 x = self.image_data_generator.apply_transform(x, params)
#     239                 x = self.image_data_generator.standardize(x)
#     240             batch_x[i] = x
#
# /opt/conda/lib/python3.8/site-packages/keras_preprocessing/image/image_data_generator.py in apply_transform(self, x, transform_parameters)
#     886
#     887         if transform_parameters.get('brightness') is not None:
# --> 888             x = apply_brightness_shift(x, transform_parameters['brightness'])
#     889
#     890         return x
#
# /opt/conda/lib/python3.8/site-packages/keras_preprocessing/image/affine_transformations.py in apply_brightness_shift(x, brightness)
#     215     x = array_to_img(x)
#     216     x = imgenhancer_Brightness = ImageEnhance.Brightness(x)
# --> 217     x = imgenhancer_Brightness.enhance(brightness)
#     218     x = img_to_array(x)
#     219     return x
#
# /opt/conda/lib/python3.8/site-packages/PIL/ImageEnhance.py in enhance(self, factor)
#      34         :rtype: :py:class:`~PIL.Image.Image`
#      35         """
# ---> 36         return Image.blend(self.degenerate, self.image, factor)
#      37
#      38
#
# /opt/conda/lib/python3.8/site-packages/PIL/Image.py in blend(im1, im2, alpha)
#    2985     im1.load()
#    2986     im2.load()
# -> 2987     return im1._new(core.blend(im1.im, im2.im, alpha))
#    2988
#    2989
#
# KeyboardInterrupt:

# %% [markdown]
# ## Model with different optimizer and loss function

# %%
model.compile(optimizer='sgd', loss='mse',
          metrics=['accuracy'])

history5 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)

# %%
plot_train_val_loss_and_acc(history5)

# %%
print_metrics(test_ds, model)
